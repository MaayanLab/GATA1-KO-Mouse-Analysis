# %% [markdown]
# # Enrichment Analyses of GATA1-knockout Mice
# Enrichment analysis performed for Ilaria Ceglia by Anders Dohlman at Ma'ayan Lab
#
# _Icahn School of Medicine at Mount Sinai_; _Department of Pharmacology and Systems Therapeutics_; _BD2K-LINCS Data Coordination and Integration Center_; _One Gustave L. Levy Place, Box 1603, New York, NY 10029 USA_
#
# ## Introduction
# Here we describe the results of microarray enrichment analysis of GATA1 knockout in PMF mice. The GATA1 transcription factor is a regulator of hematopoeisis and erythroid development, and its activation targets include in HBB, HBG1/2, ALS2, and HMBS. In previous studies by [_Zingariello et al_](http://www.ncbi.nlm.nih.gov/pubmed/23462118), GATA1-low myelofibrotic mice have were shown to have abnormal TGF-beta signaling, characterized by increased apoptosis and G1 arrest.

# %% [markdown]
# ## Methods
# We received microarray data form Ceglia containing bone marrow samples  taken from three controls and three GATA1-knockouts to profile changes in gene expression. The six myelofibrotic bone marrow samples were taken from mice were run on an Illumina microarray chip and processed by the Genomics Core Facility at Mount Sinai, where the data were quantile-normalized and reported in "FinalReport.txt". The data beneath the "Sample Gene Profile" header in the report was extracted and saved to [_gata1_gene_profile.txt_](https://github.com/abdohlman/GATA1-Analysis/blob/master/gata1_gene_profile.txt).

# %% [markdown]
# ### Data preparation
# * First, 30,854 gene profiles were extracted from "FinalReport.txt".
# * We selected the "AVG_Signal" column for each of 6 samples:
#     * **Controls**: cd1, cd2, cd3
#     * **Knockouts**: gat1, gat2, gat3
# 3. The 30854 x 6 matrix was saved as "gata1_gene_profile.txt".

# %%
# Load dependencies
# %matplotlib inline
import matplotlib
import json
import time
import requests
import os.path
import pandas as pd
import numpy as np
from IPython.display import Image
from sklearn import decomposition
from scipy.stats import zscore
import matplotlib.pyplot as plt
from IPython.display import display
from IPython.display import HTML as ipyHTML
import HTML as table2html

# Load data
df = pd.read_table('gata1_gene_profile.txt',sep='\t',index_col=0)
genelist = df.index.values
samples = df.columns.values

# %% [markdown]
# ### Quality Control
# After observing that negative signals corresponded to low confidence values, we mapped all negative values to zero. A negative value means less fluorescent than the control, ie. no signal is present. Next, we checked the microarray expression distributions using a log-normalized histogram for each sample.

# %%
pvals = df[['cd1.Detection Pval','cd2.Detection Pval','cd3.Detection Pval',
            'gat1.Detection Pval','gat2.Detection Pval','gat3.Detection Pval']]
signal = df[['cd1.AVG_Signal','cd2.AVG_Signal','cd3.AVG_Signal',
             'gat1.AVG_Signal','gat2.AVG_Signal','gat3.AVG_Signal']]

fig = plt.figure(figsize=(8, 6), dpi=80)
x = list(pd.melt(signal)['value'])
y = list(pd.melt(-np.log10(pvals))['value'])
plt.axis([-12, 12, 0, 5])
plt.scatter(x,y,s=5)
plt.xlabel('Signal',fontsize=14)
plt.ylabel('-log(p)',fontsize=14)
plt.title('Signal vs. Significance')
plt.plot([-12,1],[1,1],'r-'); plt.plot([1,1],[0,1],'r-')
plt.show()

# %%
# Replace all negative values with zero
pd.options.mode.chained_assignment = None  # default='warn'
signal[signal < 0] = 0

# Remove that dont have nonzero values?
# keep = [ i for i in range(len(signal)) if sum(1 for j in range(6) if signal.iloc[i,j]>0)>=1 ]

df = signal
samples = [x.split('.')[0] for x in df.columns.values]
df.columns = samples

print "Old matrix:",signal.shape
print "New matrix:",df.shape
# Out:
# Old matrix: (30854, 6)
# New matrix: (30854, 6)

# %% [markdown]
# Now we check the log-distribution of gene expression values in each sample.

# %%
# Log transform
logDf = np.log10(df+1)

fig = plt.figure(figsize=(8, 8), dpi=80)

# Plot histograms of data
for i in range(1,7):
    fig.add_subplot(3,2,i)
    if i%2 == 0: s,col = 'gat' + str(i/2), 'green'
    else: s,col = 'cd' + str((i+1)/2), 'red'
    n, bins, patches = plt.hist(logDf[s], 50, normed=1, facecolor=col, alpha=1)
    plt.title('\n'+s)
    if int(s[-1]) == 3: plt.xlabel('log(s+1)')
plt.tight_layout(pad=0.4, w_pad=1.0, h_pad=0.8)

# %% [markdown]
# The normalization and filtering yeilded comparable distributions.
#
# ### PCA Visualization of Samples
# To compare the samples, we performed a principal component analysis (PCA). This method visualizes the major axes of variance the genespace. A visual explanation of PCA can be found [_here_](http://setosa.io/ev/principal-component-analysis/).

# %%
# Choose 2000 genes with greatest variance and zscore them
mat = df.transpose().as_matrix()
featvars = list(np.var(mat,axis=0))
select = np.argsort(featvars)[-2000:] 
mat = zscore(mat[:,select])

# Compute PCA Coordinates and Variance
pca = decomposition.PCA(n_components=None)
pca.fit(mat)
variance_explained = pca.explained_variance_ratio_[0:2] * 100
pca_coords = pca.transform(mat)[:, 0:2]
pca1, pca2 = zip(*pca_coords)

# Plot Results
fig = plt.figure(figsize=(10, 10), dpi=80)
plt.scatter(pca1,pca2,s=75,c=[1,1,1,2,2,2])
labels = ['PC%s (%.2f' % (i,pct) + '%' + ' of variance)'
          for i,pct in enumerate(variance_explained, start=1)]
for label, x, y in zip(samples,pca1,pca2):
    plt.annotate(label,xy=(x,y),xytext = (-15, 15), textcoords = 'offset points', fontsize=16)
plt.xlabel(labels[0],fontsize=16)
plt.ylabel(labels[1],fontsize=16)
plt.axis([-60, 50, -60, 60])
plt.title("Principal Component Analysis of Samples",fontsize=20)
plt.show()

# %% [markdown]
# The clear separation between samples suggests they are a strong candidate for a robust differential expression signature.
#
# ### Processing the GATA1-/-  data into CD signatures
# The Characteristic Direction (CD) method was used to compute differentially expressed genes. It computes the unit vector perpendicular the linear discriminant hyperplane separating control and sample conditions. An in-depth description of this method was published to [_BMC Bioinformatics_](http://bmcbioinformatics.biomedcentral.com/articles/10.1186/1471-2105-15-79) in 2014. The python implementation used here can be found in the [_Ma'ayan Lab Github Repository_](https://github.com/MaayanLab/chdir/blob/master/chdir.py).

# %%
from chdir import chdir

ctrData = df[['cd1','cd2','cd3']].values
expData = df[['gat1','gat2','gat3']].values

# Get the charactersitic direction signature
[cdGenes,cdVector] = chdir(ctrData,expData,genelist)
# Out:
# Calculating the characteristic direction.
# Done chdir

# %% [markdown]
# ### Enrichment Analysis
#
# Enrichment analysis was accomplished via the Enrichr API. The top 500 most up- and down-regulated genes were submitted and enrichment results were retrieved for the following enrichment libraries:
# * MGI Mammalian Phenotype
# * Wikipathways
# * ChEA
# * PPI Hub Proteins

# %%
# Libraries to use:
libraries = ['MGI_Mammalian_Phenotype_Level_4','WikiPathways_2015','ChEA_2015','PPI_Hub_Proteins']

# Use this function to call the Enrichr API:
ENRICHR_URL = 'http://amp.pharm.mssm.edu/Enrichr/enrich'
def fetch_enrichr_results(genes, description=''):
    """Returns a dict which maps Enrichr libraries to enrichment results."""
    session = requests.session()
    payload = {'list': (None, genes), 'description': (None, description)}
    session.post(ENRICHR_URL, files=payload)
    results = {}
    for library in libraries:
        get_url = ENRICHR_URL + '?backgroundType=%s' % library
        response = session.get(get_url)
        print [str(x) for x in json.loads(response.text).keys()]
        if response.ok:
            results[library] = json.loads(response.text)[library]
        else: print "Error"
    return results

# %%
# Get 500 most up- and down-regulated genes
n = 500
geneOrder = [cdGenes[x] for x in np.argsort(cdVector)]
upGenes = geneOrder[-n:]
dnGenes = geneOrder[:n]

# Choose enrichr libraries to use
upOutput = fetch_enrichr_results('\n'.join(upGenes),'GATA1-/-')
dnOutput = fetch_enrichr_results('\n'.join(dnGenes),'GATA1-/-')
# Out:
# ['MGI_Mammalian_Phenotype_Level_4']
# ['WikiPathways_2015']
# ['ChEA_2015']
# ['PPI_Hub_Proteins']
# ['MGI_Mammalian_Phenotype_Level_4']
# ['WikiPathways_2015']
# ['ChEA_2015']
# ['PPI_Hub_Proteins']

# %%
upResults = {}
dnResults = {}

nrows = 10 # Number of terms to display per library

# Do a little formatting
for library in libraries:
    upResults[library] = []
    dnResults[library] = []
    for i in range(len(upOutput[library])):
        line = [ '{:.4e}'.format(x) if type(x)==float else x for x in upOutput[library][i][:-2]]
        if library == 'KEGG_2016': line[1] = line[1][:-22]
        elif library == 'MGI_Mammalian_Phenotype_Level_4': line[1] = line[1][10:].replace('_',' ').title()
        elif library == 'WikiPathways_2015': line[1] = line[1].replace('(',' (').title()
        elif library == 'ChEA_2015': line[1] = '_'.join([line[1].split('_')[0]]+line[1].split('_')[2:])
        genestring = ', '.join(upOutput[library][i][-2])
        upResults[library].append(line + [genestring])
    for i in range(len(dnOutput[library])):
        line = [ '{:.4e}'.format(x) if type(x)==float else x for x in dnOutput[library][i][:-2]]
        if library == 'KEGG_2016': line[1] = line[1][:-22]
        elif library == 'MGI_Mammalian_Phenotype_Level_4': line[1] = line[1][10:].replace('_',' ').title()
        elif library == 'WikiPathways_2015': line[1] = line[1].replace('(',' (').title()
        elif library == 'ChEA_2015': line[1] = '_'.join([line[1].split('_')[0]]+line[1].split('_')[2:])
        genestring = ', '.join(dnOutput[library][i][-2])
        dnResults[library].append(line + [genestring])

# %% [markdown]
# ## Results
#
# ### Enrichment Analysis
# Below are tables for MGI, KEGG, ChEA, and PPI enrichment results. Click the links below to view the full results on Enrichr:
# * [Upregulated genes](http://amp.pharm.mssm.edu/Enrichr/enrich?dataset=6j5t)
# * [Downregulated genes](http://amp.pharm.mssm.edu/Enrichr/enrich?dataset=6j5s)

# %%
fields = ["Rank","Term","p-value","z-score","Combined Score","Related Genes"]

# Now plot the tables
for library in libraries:
    htmlcode = table2html.table(upResults[library][:nrows],header_row=fields)
    print library.replace('_',' ')+": Up"
    display(ipyHTML(htmlcode))
    htmlcode = table2html.table(dnResults[library][:nrows],header_row=fields)
    print library.replace('_',' ')+": Down"
    display(ipyHTML(htmlcode))
# Out:
# MGI Mammalian Phenotype Level 4: Up
# <TABLE cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;" border="1">
#  <TR>
#   <TH>Rank</TH>
#   <TH>Term</TH>
#   <TH>p-value</TH>
#   <TH>z-score</TH>
#   <TH>Combined Score</TH>
#   <TH>Related Genes</TH>
#  </TR>
#  <TR>
#   <TD>1</TD>
#   <TD>Abnormal Adaptive Immunity </TD>
#   <TD>1.0447e-34</TD>
#   <TD>-1.3828e+00</TD>
#   <TD>1.0068e+02</TD>
#   <TD>WDR1, NCF4, GIMAP1, ARRB2, PIK3CG, FCRLA, LGALS3, ZFP36, VPREB1, RASSF5, ARHGDIB, CASP1, RAC2, SIRPA, FCER1A, FFAR2, CYTIP, PGLYRP1, B2M, JUNB, FCER1G, NME2, CYBA, FOS, MMP9, VAV1, DOK2, TYROBP, SLPI, IL1B, LTB4R1, IRF2, BTK, CHI3L1, PRTN3, PRKD2, LTB, LCP1, HCST, PPIA, H2-D1, ATF3, TLR2, CEBPB, GRN, SELPLG, CBFB, CEBPE, LYZ2, WAS, NEDD9, CXCR4, FPR2, CORO1A, GNAI2, PLAC8, CD79B, SERPINB1A, CCL5, PSAP, SPP1, NCKAP1L, CSK, CD14, MARK2, MCL1, EGR1, CD74, SEMA4A, NDFIP1, CD72, LAPTM5, RAB27A, KLF2, SELL, BCL6, KLHL6, POU2AF1, STK17B, ALOX5AP, PTPN6, CD69, MYD88, MYO1F, H2-AB1</TD>
#  </TR>
#  <TR>
#   <TD>2</TD>
#   <TD>Abnormal Immune Cell </TD>
#   <TD>1.4441e-34</TD>
#   <TD>-1.3723e+00</TD>
#   <TD>9.9919e+01</TD>
#   <TD>WDR1, NCF4, GIMAP1, ARRB2, PIK3CG, FCRLA, LGALS3, ZFP36, VPREB1, RGS1, RASSF5, ARHGDIB, CASP1, RAC2, SIRPA, FCER1A, FFAR2, CYTIP, PGLYRP1, B2M, JUNB, FCER1G, KLRA17, NME2, CYBA, FOS, MMP9, VAV1, DOK2, TYROBP, SLPI, IL1B, LTB4R1, IRF2, BTK, CHI3L1, PRTN3, PRKD2, LCP1, LTB, HCST, PPIA, H2-D1, TLR2, CEBPB, GRN, SELPLG, CBFB, CEBPE, LYZ2, WAS, NEDD9, CXCR4, FPR2, CORO1A, GNAI2, PLAC8, CD79B, SERPINB1A, CCL5, PSAP, SPP1, NCKAP1L, CSK, CD14, MARK2, MCL1, SEMA4A, CD74, EGR1, NDFIP1, CD72, LAPTM5, RAB27A, KLF2, SELL, BCL6, POU2AF1, STK17B, ALOX5AP, PTPN6, CD69, MYD88, MYO1F, H2-AB1</TD>
#  </TR>
#  <TR>
#   <TD>3</TD>
#   <TD>Abnormal Innate Immunity </TD>
#   <TD>3.0541e-26</TD>
#   <TD>-1.6268e+00</TD>
#   <TD>8.9050e+01</TD>
#   <TD>WDR1, NCF4, PIK3CG, LGALS3, ZFP36, CASP1, RAC2, SIRPA, FCER1A, FFAR2, PGLYRP1, FCER1G, DUSP1, CYBA, FOS, MMP9, VAV1, TYROBP, SLPI, IL1B, LTB4R1, BTK, CHI3L1, PRTN3, LCP1, HCST, TLR2, GRN, SELPLG, CEBPE, LYZ2, WAS, FPR2, CORO1A, GNAI2, PLAC8, SERPINB1A, PSAP, SPP1, NCKAP1L, CD14, EGR1, RAB27A, SELL, ALOX5AP, CD69, MYD88, MYO1F, H2-AB1</TD>
#  </TR>
#  <TR>
#   <TD>4</TD>
#   <TD>Abnormal Immune Serum </TD>
#   <TD>1.9200e-26</TD>
#   <TD>-1.5401e+00</TD>
#   <TD>8.4738e+01</TD>
#   <TD>ARRB2, LITAF, PIK3CG, FCRLA, VPREB1, LGALS1, RGS1, CASP1, RAC2, FCER1A, FFAR2, B2M, JUNB, FCER1G, DUSP1, KLRA17, NME2, MIF, FOS, MMP9, VAV1, TYROBP, SLPI, IL1B, LTB4R1, IRF2, BTK, CHI3L1, PRKD2, LCP1, LTB, PPIA, HCST, ATF3, TLR2, GRN, CEBPB, SELPLG, CBFB, LYZ2, WAS, FPR2, CORO1A, GNAI2, CD79B, SERPINB1A, CCL5, SPP1, CCL3, NCKAP1L, CD14, MARK2, MCL1, SEMA4A, EGR1, CD74, CD72, LAPTM5, KLF2, BCL6, STK17B, POU2AF1, PTPN6, CD69, MYD88, H2-AB1</TD>
#  </TR>
#  <TR>
#   <TD>5</TD>
#   <TD>Abnormal Antigen Presenting </TD>
#   <TD>1.0788e-24</TD>
#   <TD>-1.5338e+00</TD>
#   <TD>7.8731e+01</TD>
#   <TD>WDR1, PIK3CG, FCRLA, LGALS3, ZFP36, VPREB1, RGS1, RASSF5, ARHGDIB, CASP1, SIRPA, FCER1A, B2M, JUNB, FCER1G, KLRA17, FOS, MMP9, VAV1, TYROBP, SLPI, IL1B, LTB4R1, IRF2, BTK, CHI3L1, PRKD2, LCP1, LTB, HCST, PPIA, TLR2, CEBPB, GRN, CBFB, LYZ2, WAS, NEDD9, FPR2, CORO1A, GNAI2, CD79B, PSAP, SPP1, NCKAP1L, CD14, MARK2, MCL1, CD74, SEMA4A, EGR1, CD72, KLF2, BCL6, SELL, POU2AF1, PTPN6, CD69, MYD88, H2-AB1</TD>
#  </TR>
#  <TR>
#   <TD>6</TD>
#   <TD>Abnormal Blood Cell </TD>
#   <TD>2.0176e-28</TD>
#   <TD>-1.2970e+00</TD>
#   <TD>7.6613e+01</TD>
#   <TD>WDR1, GIMAP1, HBB-B1, CD3D, PIK3CG, GPI1, LGALS3, VPREB1, RASSF5, ARHGDIB, RAC2, FCER1A, SIRPA, CTSG, FFAR2, CYTIP, JUNB, B2M, CLIC1, CPA3, FCER1G, KLRA17, NME2, FOS, MIF, MMP9, VAV1, APRT, DOK3, TYROBP, SLPI, LTB4R1, IRF2, BTK, CHI3L1, LTB, HCST, PPIA, GAPDH, H2-D1, TLR2, CEBPB, VCP, GRN, SELPLG, CBFB, CEBPE, LYZ2, HDC, WAS, CXCR4, NEDD9, FPR2, GATA2, CORO1A, GNAI2, ZFP36L1, PLAC8, CD79B, SERPINB1A, LDHA, CCL5, PSAP, SPP1, CCL3, NCKAP1L, CSK, MARK2, MCL1, EGR1, CD74, SEMA4A, NDFIP1, CD72, LAPTM5, RAB27A, KLF2, PSMB8, PSMB9, KLF6, SELL, KLHL6, STK17B, POU2AF1, BGLAP2, CD9, PTPN6, MAN2B1, CD69, TGFBI, CLEC2D, MYD88, H2-AB1</TD>
#  </TR>
#  <TR>
#   <TD>7</TD>
#   <TD>Abnormal Response To </TD>
#   <TD>1.6104e-19</TD>
#   <TD>-1.8909e+00</TD>
#   <TD>7.5008e+01</TD>
#   <TD>CEBPB, GRN, CEBPE, LYZ2, NCF4, CORO1A, PIK3CG, GNAI2, PLAC8, LGALS3, SERPINB1A, CASP1, SPP1, CCL3, RAC2, FFAR2, CTSG, CSK, CD14, PGLYRP1, B2M, CAMP, CD74, FCER1G, KLRA17, CYBA, MIF, FOS, MMP9, VAV1, PSMB9, TYROBP, SLPI, IL1B, POU2AF1, IRF2, ADPRH, LCN2, PTPN6, LTB, LCP1, HCST, MYD88, H2-D1, TLR2, H2-AB1</TD>
#  </TR>
#  <TR>
#   <TD>8</TD>
#   <TD>Abnormal Immune System </TD>
#   <TD>3.9343e-28</TD>
#   <TD>-1.2745e+00</TD>
#   <TD>7.4796e+01</TD>
#   <TD>WDR1, GIMAP1, CD3D, PIK3CG, LGALS3, VPREB1, RASSF5, ARHGDIB, RAC2, FCER1A, SIRPA, FFAR2, CTSG, CYTIP, JUNB, B2M, CPA3, FCER1G, KLRA17, FOS, MIF, MMP9, VAV1, DOK3, TYROBP, SLPI, LTB4R1, IRF2, BTK, CHI3L1, LTB, HCST, PPIA, H2-D1, TLR2, CEBPB, VCP, GRN, SELPLG, CBFB, CEBPE, LYZ2, HDC, WAS, CXCR4, NEDD9, FPR2, CORO1A, GNAI2, PLAC8, CD79B, SERPINB1A, LDHA, CCL5, PSAP, CCL3, SPP1, NCKAP1L, CSK, MARK2, MCL1, EGR1, CD74, SEMA4A, CD72, NDFIP1, LAPTM5, KLF2, PSMB8, PSMB9, SELL, KLHL6, STK17B, POU2AF1, BGLAP2, PTPN6, MAN2B1, CD69, TGFBI, CLEC2D, MYD88, H2-AB1</TD>
#  </TR>
#  <TR>
#   <TD>9</TD>
#   <TD>Abnormal Bone Marrow </TD>
#   <TD>2.8679e-20</TD>
#   <TD>-1.2811e+00</TD>
#   <TD>5.2879e+01</TD>
#   <TD>WDR1, GIMAP1, HBB-B1, CD3D, PIK3CG, LGALS3, VPREB1, RASSF5, ARHGDIB, RAC2, SIRPA, FCER1A, CTSG, B2M, CLIC1, CPA3, FCER1G, FOS, MIF, MMP9, VAV1, TYROBP, SLPI, LTB4R1, IRF2, BTK, LTB, H2-D1, CEBPB, SELPLG, CBFB, CEBPE, LYZ2, WAS, CXCR4, GATA2, CORO1A, GNAI2, CD79B, LDHA, CCL5, SPP1, NCKAP1L, CSK, MARK2, MCL1, EGR1, CD74, SEMA4A, NDFIP1, CD72, LAPTM5, RAB27A, KLF2, BCL6, SELL, KLHL6, STK17B, POU2AF1, PTPN6, CD69, MYD88, H2-AB1</TD>
#  </TR>
#  <TR>
#   <TD>10</TD>
#   <TD>Abnormal Humoral Immune </TD>
#   <TD>3.7821e-13</TD>
#   <TD>-1.8841e+00</TD>
#   <TD>4.7298e+01</TD>
#   <TD>CBFB, FPR2, PIK3CG, GNAI2, FCRLA, CD79B, LGALS3, VPREB1, RGS1, FCER1A, B2M, JUNB, MARK2, MCL1, CD74, FCER1G, CD72, MMP9, VAV1, KLF2, BCL6, POU2AF1, LTB4R1, IRF2, BTK, CHI3L1, PTPN6, PRKD2, CD69, LTB, PPIA, MYD88, ATF3, H2-AB1, TLR2</TD>
#  </TR>
# </TABLE>
# MGI Mammalian Phenotype Level 4: Down
# <TABLE cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;" border="1">
#  <TR>
#   <TH>Rank</TH>
#   <TH>Term</TH>
#   <TH>p-value</TH>
#   <TH>z-score</TH>
#   <TH>Combined Score</TH>
#   <TH>Related Genes</TH>
#  </TR>
#  <TR>
#   <TD>1</TD>
#   <TD>Abnormal Erythrocyte Physiolo </TD>
#   <TD>2.5327e-12</TD>
#   <TD>-2.0634e+00</TD>
#   <TD>4.4587e+01</TD>
#   <TD>BNIP3L, CD59A, FECH, EIF2AK1, UROS, MAFG, SPNB1, SLC4A1, EPB4.9, ANK1, KLF1</TD>
#  </TR>
#  <TR>
#   <TD>2</TD>
#   <TD>Abnormal Nucleus Morphology </TD>
#   <TD>7.6736e-10</TD>
#   <TD>-1.8216e+00</TD>
#   <TD>3.0622e+01</TD>
#   <TD>RB1, GADD45A, CDCA8, SLC4A1, KIF22, CENPA, FZR1, LMNA, E2F1, BIRC5, MCM4, LBR, MCM2</TD>
#  </TR>
#  <TR>
#   <TD>3</TD>
#   <TD>Prenatal Lethality </TD>
#   <TD>5.4469e-13</TD>
#   <TD>-1.2057e+00</TD>
#   <TD>2.7070e+01</TD>
#   <TD>FEN1, ALAS2, AHCTF1, MCM7, TFRC, LDB1, HS6ST1, AQP1, PSMD4, UROD, FTH1, FNTB, NUSAP1, LBR, HIST1H1C, TMOD1, ATP6AP1, APLP2, SPHK1, LMO2, KIF22, PLRG1, RANGAP1, TAL1, SPNB1, TAX1BP1, RPL24, MCM4, BIRC5, XIST, MCM6, MCM2, FECH, UHRF1, COX17, ODC1, CDCA8, CENPA, UGCG, CCNB1, FZR1, BAG1, E2F1, TXNRD2, UROS, RPA1, HRAS1, LSM4, KLF1, GFI1B, CSDA, SLC6A9, COL5A1, MAFG, SSBP3</TD>
#  </TR>
#  <TR>
#   <TD>4</TD>
#   <TD>Abnormal Blood Cell </TD>
#   <TD>8.3648e-12</TD>
#   <TD>-1.2970e+00</TD>
#   <TD>2.7003e+01</TD>
#   <TD>RB1, ALAS2, DYRK3, FEN1, TFRC, MCM7, SLC4A1, ICAM4, HBA-A1, MPO, AQP1, RABGEF1, CTSE, LBR, TMOD1, BNIP3L, KLF13, RSAD2, SPHK1, LMO2, H2AFX, ANK1, TAL1, PSME3, SPNB1, TXNIP, MCM4, BIRC5, CD47, MCM6, S100A9, ATF4, MCM2, GYPA, FECH, TSPAN33, SAMSN1, PRDX2, FZR1, CD59A, E2F1, E2F2, PRNP, TXNRD2, GADD45A, EIF2AK1, UROS, RPA1, EPB4.9, KLF1, GFI1B, MAFG</TD>
#  </TR>
#  <TR>
#   <TD>5</TD>
#   <TD>Abnormal Bone Marrow </TD>
#   <TD>3.9938e-10</TD>
#   <TD>-1.3393e+00</TD>
#   <TD>2.3090e+01</TD>
#   <TD>RB1, DYRK3, TFRC, FECH, SLC4A1, HBA-A1, TSPAN33, SAMSN1, PRDX2, FZR1, CD59A, E2F1, E2F2, CTSE, LBR, BNIP3L, PRNP, KLF13, RSAD2, GADD45A, UROS, SPHK1, LMO2, H2AFX, EPB4.9, ANK1, KLF1, GFI1B, TAL1, MAFG, PSME3, SPNB1, MCM4, BIRC5, TXNIP, MCM2, ATF4</TD>
#  </TR>
#  <TR>
#   <TD>6</TD>
#   <TD>Abnormal Mineral Homeostasis </TD>
#   <TD>1.0858e-06</TD>
#   <TD>-1.8841e+00</TD>
#   <TD>1.9111e+01</TD>
#   <TD>PRNP, ALAS2, TFRC, EIF2AK1, UROS, SLC4A1, MT1, ANK1, KLF1, PRDX2, FTH1, SPNB1, TXNIP</TD>
#  </TR>
#  <TR>
#   <TD>7</TD>
#   <TD>Abnormal Cell Cycle </TD>
#   <TD>4.8899e-07</TD>
#   <TD>-1.7455e+00</TD>
#   <TD>1.8892e+01</TD>
#   <TD>GPX1, GADD45A, CDCA8, PLRG1, CENPA, FZR1, FNTB, E2F1, NUSAP1, RPL24, BIRC5, MCM4, MCM2</TD>
#  </TR>
#  <TR>
#   <TD>8</TD>
#   <TD>Abnormal Cell Proliferation </TD>
#   <TD>3.0008e-07</TD>
#   <TD>-1.6846e+00</TD>
#   <TD>1.8831e+01</TD>
#   <TD>FEN1, GPX1, TXNRD2, GADD45A, H2AFX, RPA1, PLRG1, HS6ST1, SOD1, FZR1, PSME3, FNTB, E2F1, MCM4, SSBP3, ATF4, MCM2</TD>
#  </TR>
#  <TR>
#   <TD>9</TD>
#   <TD>Abnormal Cell Death </TD>
#   <TD>1.5764e-07</TD>
#   <TD>-1.4739e+00</TD>
#   <TD>1.7198e+01</TD>
#   <TD>RB1, FEN1, GPX1, TFRC, LMO2, CDCA8, CENPA, SOD1, PRDX2, PACS2, TAL1, FTH1, FNTB, E2F1, E2F2, BIRC5, RPL24, GCLM, LBR, SSBP3, ANK, CTSB, HIST1H1C</TD>
#  </TR>
#  <TR>
#   <TD>10</TD>
#   <TD>Abnormal Redox Activity </TD>
#   <TD>1.4205e-05</TD>
#   <TD>-1.7525e+00</TD>
#   <TD>1.4045e+01</TD>
#   <TD>GPX1, PON2, FTH1, MT1, GCLM, ADIPOR1, SOD1</TD>
#  </TR>
# </TABLE>
# WikiPathways 2015: Up
# <TABLE cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;" border="1">
#  <TR>
#   <TH>Rank</TH>
#   <TH>Term</TH>
#   <TH>p-value</TH>
#   <TH>z-score</TH>
#   <TH>Combined Score</TH>
#   <TH>Related Genes</TH>
#  </TR>
#  <TR>
#   <TD>1</TD>
#   <TD>Cytoplasmic Ribosomal Proteins (Mus Musculus)</TD>
#   <TD>4.0491e-11</TD>
#   <TD>-1.9144e+00</TD>
#   <TD>3.5443e+01</TD>
#   <TD>RPL32, RPL31, RPL34, RPS6, RPL10A, RPL9, RPS14, RPS19, RPL36AL, RPL27A, RPS6KA1, RPS3, RPL27, RPL18, RPS11, RPL39, RPS13, RPS12</TD>
#  </TR>
#  <TR>
#   <TD>2</TD>
#   <TD>Cytoplasmic Ribosomal Proteins (Homo Sapiens)</TD>
#   <TD>1.5515e-08</TD>
#   <TD>-1.9086e+00</TD>
#   <TD>2.5305e+01</TD>
#   <TD>RPS9, RPL32, RPL31, RPL34, RPS6, RPL10A, RPL9, RPS14, RPS19, RPL27A, RPS6KA1, RPS3, RPL27, RPL18, RPL29, RPS11, RPL39, RPS13, RPS12</TD>
#  </TR>
#  <TR>
#   <TD>3</TD>
#   <TD>Chemokine Signaling Pathway (Mus Musculus)</TD>
#   <TD>1.3142e-04</TD>
#   <TD>-2.0494e+00</TD>
#   <TD>9.4672e+00</TD>
#   <TD>WAS, CXCR4, ARRB2, CXCL2, PIK3CG, VAV1, GNAI2, GNG10, ADRBK1, CCL5, GNB2, CCL4, RAC2, CSK, PRKACB</TD>
#  </TR>
#  <TR>
#   <TD>4</TD>
#   <TD>Regulation Of Toll-Like Receptor Signaling Pathway (Homo Sapiens)</TD>
#   <TD>1.4247e-03</TD>
#   <TD>-1.9810e+00</TD>
#   <TD>6.1084e+00</TD>
#   <TD>CCL5, IL1B, CCL4, BTK, CCL3, SPP1, PTPN6, CD14, FOS, MYD88, PIK3CG, TLR2</TD>
#  </TR>
#  <TR>
#   <TD>5</TD>
#   <TD>Toll-Like Receptor Signaling Pathway (Homo Sapiens)</TD>
#   <TD>1.2048e-03</TD>
#   <TD>-1.9598e+00</TD>
#   <TD>6.0431e+00</TD>
#   <TD>CCL5, IL1B, CCL4, CCL3, SPP1, CD14, FOS, MYD88, PIK3CG, TLR2</TD>
#  </TR>
#  <TR>
#   <TD>6</TD>
#   <TD>Regulation Of Actin Cytoskeleton (Homo Sapiens)</TD>
#   <TD>1.2759e-03</TD>
#   <TD>-1.8541e+00</TD>
#   <TD>5.7172e+00</TD>
#   <TD>ACTN1, TMSB4X, RAC2, WAS, CSK, ARPC5, CD14, IQGAP1, PFN1, ACTB, PIK3CG, VAV1</TD>
#  </TR>
#  <TR>
#   <TD>7</TD>
#   <TD>Il1 And Megakaryotyces In Obesity (Homo Sapiens)</TD>
#   <TD>1.0908e-03</TD>
#   <TD>-1.7590e+00</TD>
#   <TD>5.4242e+00</TD>
#   <TD>IL1B, FCER1A, MMP9, MYD88, TLR2</TD>
#  </TR>
#  <TR>
#   <TD>8</TD>
#   <TD>Kit Receptor Signaling Pathway (Homo Sapiens)</TD>
#   <TD>2.2431e-03</TD>
#   <TD>-1.7770e+00</TD>
#   <TD>5.0942e+00</TD>
#   <TD>RPS6, RPS6KA1, BTK, PTPN6, FOS, JUNB, VAV1</TD>
#  </TR>
#  <TR>
#   <TD>9</TD>
#   <TD>Spinal Cord Injury (Homo Sapiens)</TD>
#   <TD>2.2753e-03</TD>
#   <TD>-1.7552e+00</TD>
#   <TD>5.0318e+00</TD>
#   <TD>EGR1, LGALS3, ZFP36, IL1B, FOS, LTB, MIF, CXCL2, MMP9, RHOB</TD>
#  </TR>
#  <TR>
#   <TD>10</TD>
#   <TD>Regulation Of Actin Cytoskeleton (Mus Musculus)</TD>
#   <TD>4.6197e-03</TD>
#   <TD>-1.7411e+00</TD>
#   <TD>4.1076e+00</TD>
#   <TD>ACTN1, RAC2, WAS, CSK, ARPC5, CD14, IQGAP1, PFN1, ACTB, PIK3CG, VAV1</TD>
#  </TR>
# </TABLE>
# WikiPathways 2015: Down
# <TABLE cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;" border="1">
#  <TR>
#   <TH>Rank</TH>
#   <TH>Term</TH>
#   <TH>p-value</TH>
#   <TH>z-score</TH>
#   <TH>Combined Score</TH>
#   <TH>Related Genes</TH>
#  </TR>
#  <TR>
#   <TD>1</TD>
#   <TD>G1 To S Cell Cycle Control (Homo Sapiens)</TD>
#   <TD>2.6252e-08</TD>
#   <TD>-1.9624e+00</TD>
#   <TD>2.4010e+01</TD>
#   <TD>RB1, MCM7, GADD45A, RPA1, CCNB1, TFDP2, RPA3, E2F1, E2F2, MCM4, MCM5, MCM6, MCM2</TD>
#  </TR>
#  <TR>
#   <TD>2</TD>
#   <TD>G1 To S Cell Cycle Control (Mus Musculus)</TD>
#   <TD>6.9226e-08</TD>
#   <TD>-1.9359e+00</TD>
#   <TD>2.3151e+01</TD>
#   <TD>RB1, MCM7, TFDP2, GADD45A, RPA3, E2F1, RPA1, E2F2, MCM4, MCM5, MCM6, MCM2</TD>
#  </TR>
#  <TR>
#   <TD>3</TD>
#   <TD>Cytoplasmic Ribosomal Proteins (Homo Sapiens)</TD>
#   <TD>7.7105e-07</TD>
#   <TD>-1.8257e+00</TD>
#   <TD>1.9105e+01</TD>
#   <TD>RPL41, RPL3, RPS8, RPL23, RPL36A, RPS3A, RPS26, RPL7A, RPS16, RPS29, RPL24, RPLP2, RPS2, UBA52, RPS24</TD>
#  </TR>
#  <TR>
#   <TD>4</TD>
#   <TD>Dna Replication (Homo Sapiens)</TD>
#   <TD>1.6538e-06</TD>
#   <TD>-1.7323e+00</TD>
#   <TD>1.7121e+01</TD>
#   <TD>CDT1, MCM7, RPA3, RPA1, MCM4, MCM5, MCM6, UBA52, MCM2</TD>
#  </TR>
#  <TR>
#   <TD>5</TD>
#   <TD>Dna Replication (Mus Musculus)</TD>
#   <TD>1.3686e-05</TD>
#   <TD>-1.7528e+00</TD>
#   <TD>1.4103e+01</TD>
#   <TD>CDT1, MCM7, RPA3, RPA1, MCM4, MCM5, MCM6, MCM2</TD>
#  </TR>
#  <TR>
#   <TD>6</TD>
#   <TD>Rb In Cancer (Homo Sapiens)</TD>
#   <TD>1.3854e-05</TD>
#   <TD>-1.7141e+00</TD>
#   <TD>1.3791e+01</TD>
#   <TD>RB1, CDT1, CCNB1, MCM7, TFDP2, RPA3, E2F1, RPA1, E2F2, MCM4, MCM6</TD>
#  </TR>
#  <TR>
#   <TD>7</TD>
#   <TD>Heme Biosynthesis (Homo Sapiens)</TD>
#   <TD>5.8392e-07</TD>
#   <TD>-1.3090e+00</TD>
#   <TD>1.3769e+01</TD>
#   <TD>ALAD, ALAS2, FECH, UROD, UROS, PPOX</TD>
#  </TR>
#  <TR>
#   <TD>8</TD>
#   <TD>Cytoplasmic Ribosomal Proteins (Mus Musculus)</TD>
#   <TD>2.0560e-05</TD>
#   <TD>-1.6649e+00</TD>
#   <TD>1.2935e+01</TD>
#   <TD>RPS26, RPL7A, RPL3, RPS16, RPS29, RPS8, RPL24, RPLP2, RPS2, RPS24</TD>
#  </TR>
#  <TR>
#   <TD>9</TD>
#   <TD>Heme Biosynthesis (Mus Musculus)</TD>
#   <TD>5.8392e-07</TD>
#   <TD>-9.5853e-01</TD>
#   <TD>1.0083e+01</TD>
#   <TD>ALAD, ALAS2, FECH, UROD, UROS, PPOX</TD>
#  </TR>
#  <TR>
#   <TD>10</TD>
#   <TD>Translation Factors (Mus Musculus)</TD>
#   <TD>1.9444e-04</TD>
#   <TD>-1.5767e+00</TD>
#   <TD>8.8998e+00</TD>
#   <TD>EEF1B2, EEF1G, EIF5, EEF1D, EIF2AK1, EIF3I, PABPC1</TD>
#  </TR>
# </TABLE>
# ChEA 2015: Up
# <TABLE cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;" border="1">
#  <TR>
#   <TH>Rank</TH>
#   <TH>Term</TH>
#   <TH>p-value</TH>
#   <TH>z-score</TH>
#   <TH>Combined Score</TH>
#   <TH>Related Genes</TH>
#  </TR>
#  <TR>
#   <TD>1</TD>
#   <TD>MYB_ChIP-Seq_ERMYB_Mouse</TD>
#   <TD>4.1702e-46</TD>
#   <TD>-1.9420e+00</TD>
#   <TD>1.9349e+02</TD>
#   <TD>SAMD9L, MIDN, TNFAIP8, OLFML2B, ALAS1, MS4A3, BTG1, RPL31, RAB3D, PYGL, GLIPR1, ZFP36, SIRPA, CTSG, OSTF1, JUNB, TMSB10, RAB8A, NDEL1, CAP1, 1810033B17RIK, H2AFY, DUSP1, EMP3, APRT, RHOB, ACLY, DOK3, CLEC4D, SLPI, FCGR4, CDC42EP3, SPATA13, IRF2, ADSSL1, LCP1, SGK1, CEBPB, HDC, NEDD9, MGST2, CXCR4, UNC84B, GNAI2, ZFP36L1, PLAC8, CCL9, GNG10, CCL5, ELA2, LRRC8D, NADK, MCL1, OSBPL9, CMTM7, PLEKHA2, OSM, RAB27A, KLF6, BCL6, SELL, STK17B, ALOX5AP, ZYX, PTPN6, CALM3, DEGS1, CD69, PLP2, PI16, CRLF3, MYO1F</TD>
#  </TR>
#  <TR>
#   <TD>2</TD>
#   <TD>MECOM_ChIP-Seq_KASUMI_Mouse</TD>
#   <TD>3.9026e-58</TD>
#   <TD>-1.4420e+00</TD>
#   <TD>1.8203e+02</TD>
#   <TD>GMFG, NCF4, FCNB, KRTCAP2, RGS1, ARHGDIB, MYEOV2, SIRPA, PGLYRP1, RPL39, JUNB, B2M, KLRA17, STX7, TALDO1, HMHA1, CYBA, SCAMP2, 0910001L09RIK, MYL6, DOK2, DOK3, CLEC4D, LTB4R1, BTK, PRKD2, PRTN3, RPL27, ARL8A, LY6E, PRR13, CBFB, LYZ2, TWF2, MGST2, CORO1A, PLAC8, LDHA, GNG10, NCKAP1L, SLC15A3, ATP6V1D, NADK, MARK2, MCL1, NAPSA, RAB27A, ARPC5, AI467606, SLC6A6, ARHGAP30, SELL, LRP10, WDR1, ATP2A3, LRMP, PYGL, ARRB2, TREM3, RCSD1, LITAF, SLC2A6, CXCL2, PIK3CG, ARHGAP4, PSTPIP1, GLIPR1, LBH, ALDH2, RAC2, TSPO, CTSG, CLIC1, CAP1, CD52, FCER1G, ANXA2, ANXA3, APRT, IL1B, LCP1, LTB, SGK1, HCST, GAPDH, TLR2, PNKP, 1110003E01RIK, NEDD9, COX5A, CLN5, CCL9, CCL3, CSK, RNF130, PLEKHA2, OSM, LAPTM5, ARID3A, PPP1CA, DHRS7, OSTM1, KLHL6, ALOX5AP, 2310009A05RIK, PTPN6, PI16, CD69, CRLF3, MYO1F</TD>
#  </TR>
#  <TR>
#   <TD>3</TD>
#   <TD>SPI1_ChIP-ChIP_GC-B_Mouse</TD>
#   <TD>9.2523e-32</TD>
#   <TD>-2.1571e+00</TD>
#   <TD>1.4604e+02</TD>
#   <TD>HIST2H2AA2, EIF4A1, NDUFA13, TRIM30, GMFG, NCF4, LST1, DBI, LRMP, RCSD1, ACTB, UBL5, RPS14, ZFP36, HNRPL, RPS19, TMSB4X, CASP1, OSTF1, RPS11, JUNB, B2M, CAP1, CD52, FOS, EMP3, SCAMP2, 2310014H01RIK, DOK3, SLPI, IGH-6, IL1B, ADPRH, IRF2, BTK, ERP29, PRKD2, LCP1, LTB, HCST, H2-D1, PRR13, CBFB, PIRA4, WAS, ATP5L, PRDX5, H2-DMB1, PSAP, RPS3, NCKAP1L, SLC15A3, MYLC2B, ATP6V1D, PTPN18, NDFIP1, CD72, PLEKHA2, SHFM1, LAPTM5, AI467606, SCOTIN, PSMB8, PPP1CA, TSPAN14, POU2AF1, GNB2, RPL27A, PTPN6, PLP2, P4HB, CD69, CRLF3, LRP10</TD>
#  </TR>
#  <TR>
#   <TD>4</TD>
#   <TD>EKLF_ChIP-Seq_ERYTHROCYTE_Mouse</TD>
#   <TD>3.2829e-37</TD>
#   <TD>-1.5977e+00</TD>
#   <TD>1.2692e+02</TD>
#   <TD>HIBADH, RPL32, WDR1, ARPC1B, DBI, ARRB2, ENO1, RPL10A, MRPL33, RPS14, KRTCAP2, LGALS1, ALDH2, RAC2, MYEOV2, SH3BGRL3, RPS11, CLIC1, LYPLA2, RPS9, H2AFY, LMO4, 2700094K13RIK, NME2, HMHA1, CYBA, EMP3, MIF, PGD, EEF1A1, ACLY, MYL6, COX7A2L, PSMA4, 2010107E04RIK, NGP, SPATA13, ADPRH, TAGLN2, RPL27, PRTN3, LCP1, SLC25A5, RPL29, PFN1, PPIA, PFDN5, LY6E, ATP6V0E, CD63, CDCA7, CORO1A, GNAI2, CST3, LDHA, GNG10, ADRBK1, PSAP, RPS3, CSK, RNF130, CMTM7, PKM2, TBCA, PPP1CA, ZYX, PTPN6, CALM3, LRP10, 2310016M24RIK, ITM2B</TD>
#  </TR>
#  <TR>
#   <TD>5</TD>
#   <TD>STAT4_ChIP-ChIP_TH1  _Mouse</TD>
#   <TD>5.6108e-23</TD>
#   <TD>-2.5581e+00</TD>
#   <TD>1.2362e+02</TD>
#   <TD>MIDN, WDR1, RNPEPL1, GMFG, GIMAP1, HBB-B1, LRMP, FAIM3, PIGX, GLIPR1, ZFP36, RGS1, RASSF5, RAC2, CASP1, EMB, JUNB, B2M, CLIC1, 1110032A13RIK, IFITM6, NDEL1, PSENEN, PDIA3, CD52, HIST1H2AO, CYBA, FOS, 2310014H01RIK, IRF2, BOLA2, ARHGEF3, PRTN3, RPL27, LCP1, LTB, ATF3, VPS28, H2-D1, CBFB, CORO1A, GNAI2, ZFP36L1, PLAC8, CCL9, 2010107H07RIK, AXUD1, ADRBK1, MCL1, OSBPL9, SEMA4A, PKM2, NDUFA3, OSM, RAB27A, ARID3A, LOC546015, SCOTIN, PSMB8, PSMB9, ARHGAP30, BCL6, LCN2, PTPN6, PLP2, CD69, MYD88</TD>
#  </TR>
#  <TR>
#   <TD>6</TD>
#   <TD>SPI1_ChIP-Seq_NB4_Human</TD>
#   <TD>1.8150e-47</TD>
#   <TD>-1.0543e+00</TD>
#   <TD>1.0792e+02</TD>
#   <TD>EIF4A1, NDUFA13, IFITM1, IFITM2, ZFAND3, GMFG, LST1, NCF4, FAIM3, RPL9, LGALS1, RPS19, RGS1, RASSF5, RPS6KA1, ARHGDIB, COTL1, OSTF1, RPS11, ATP6V1E1, JUNB, TMSB10, B2M, RPS13, PDIA3, LMO4, RPS6, TALDO1, CYBA, MIF, RAB32, MYL6, TYROBP, DOK3, BTK, ERP29, RIN3, PRKD2, PRTN3, RPL27, S100A8, IQGAP1, GATA2, CORO1A, PSAP, NCKAP1L, CD14, SLC15A3, ATP6V1D, S100A11, MARK2, MCL1, MCTS1, ARPC5, HIGD2A, SLC6A6, ARHGAP30, ARPC3, GNB2, RPL27A, LRP10, MYD88, ITM2B, TNFAIP8, ALAS1, BTG1, ARPC1B, ATP2A3, LRMP, PYGL, ARRB2, PIK3CG, ARHGAP4, LASP1, GLIPR1, PSTPIP1, GM2A, RAC2, SH3BGRL3, CTSG, CLIC1, CAMP, RAB8A, CD52, FCER1G, DUSP1, TSC22D3, NME2, EMP3, FOS, VAV1, PSMA4, DNAJC7, IL1B, IRF2, LCP1, HCST, PFDN5, CEBPB, SELPLG, CEBPE, PNKP, POMP, PRCP, ATP1A1, GNAI2, CCL4, SPP1, RPS3, LRRC8D, CSK, PTPN18, NDUFA7, CD72, CMTM6, LAPTM5, OSM, PSMB8, LRG1, ALOX5AP, PTPN6, PI16</TD>
#  </TR>
#  <TR>
#   <TD>7</TD>
#   <TD>TAL1_ChIP-Seq_HPC-7_Mouse</TD>
#   <TD>4.8912e-36</TD>
#   <TD>-1.3981e+00</TD>
#   <TD>1.0760e+02</TD>
#   <TD>EIF4A1, MIDN, OLFML2B, BTG1, ZFAND3, RPL31, ARPC1B, GIMAP1, LST1, ATP2A3, LRMP, ARRB2, RPL10A, FAIM3, ACTB, RPS14, PSTPIP1, KRTCAP2, VPREB1, ZFP36, LBH, RPS19, RGS1, TMSB4X, MYEOV2, SH3BGRL3, JUNB, TMSB10, B2M, CLIC1, RPS12, PDIA3, RPS9, DUSP1, RPS6, SSU72, FOS, EMP3, VAV1, SCAMP2, 2310014H01RIK, RHOB, EEF1A1, ACLY, DOK2, CLEC4D, IRF2, TAGLN2, RPL27, LTB, PFN1, HCST, PPIA, ARL8A, PRR13, ATP6V0E, CD63, CEBPE, GLO1, POMP, MGST2, CXCR4, GATA2, COX5A, CLN5, LDHA, CCL9, RPS3, RPL18, NADK, SERF2, MCL1, CMTM7, EGR1, NDUFA7, NDFIP1, CMTM6, LAPTM5, ARPC5, KLF6, OSTM1, POU2AF1, RPL27A, ZYX, PI16, MYO1F, MYD88</TD>
#  </TR>
#  <TR>
#   <TD>8</TD>
#   <TD>KLF4_ChIP-ChIP_MESC_Mouse</TD>
#   <TD>9.1238e-27</TD>
#   <TD>-1.7496e+00</TD>
#   <TD>9.9107e+01</TD>
#   <TD>HIST2H2AA2, IFITM1, D3UCLA1, IFITM2, RPL31, GMFG, RAB3D, ATP2A3, SLC2A3, ENO1, ACTB, TRIOBP, LGALS3, RPS14, LASP1, KRTCAP2, ZFP36, RPS19, TSPO, RPS11, JUNB, CLIC1, RAB8A, TPD52, HIST1H2AO, ANXA2, ACTN1, HMHA1, ATP1B1, APRT, EEF1A1, ADPRH, CDC42EP3, BOLA2, TAGLN2, SLC25A5, PFN1, GAPDH, ATF3, ARL8A, PRR13, HDC, PNKP, CDCA7, UNC84B, IQGAP1, COX5A, ZFP36L1, CST3, PRDX5, P2RY5, SPP1, CKB, RPL18, MYLC2B, MARK2, MCL1, EGR1, PKM2, CMTM6, DSTN, ARID3A, KLF2, ARHGAP30, GNB2, CD9, PTPN6, CALM3</TD>
#  </TR>
#  <TR>
#   <TD>9</TD>
#   <TD>STAT3_ChIP-Seq_CD4+T_Mouse</TD>
#   <TD>4.3199e-11</TD>
#   <TD>-4.3237e+00</TD>
#   <TD>9.6804e+01</TD>
#   <TD>TNFAIP8, BTG1, MAST3, RPL34, ACTB, GLIPR1, ZFP36, RGS1, RAC2, FFAR2, EMB, CLIC1, IFITM6, CAP1, TPD52, CD52, H2AFY, FOS, EMP3, MMP9, EG268795, SPATA13, IRF2, LOC666676, PRKD2, ATF3, H2-D1, LY6E, SELPLG, CXCR4, IQGAP1, ZFP36L1, PLAC8, AXUD1, CCL5, S100A11, EGR1, 1200013B08RIK, NDFIP1, OSM, RAB27A, ARID3A, ASPRV1, ARHGAP30, BCL6, ARPC3, KLHL6, STK17B, ALOX5AP, CD69, ITM2B</TD>
#  </TR>
#  <TR>
#   <TD>10</TD>
#   <TD>SPI1_ChIP-Seq_ERYTHROLEUKEMIA_Mouse</TD>
#   <TD>2.9503e-35</TD>
#   <TD>-1.2593e+00</TD>
#   <TD>9.4888e+01</TD>
#   <TD>TNFAIP8, BTG1, RPL32, MAST3, RPL31, GMFG, LST1, ATP2A3, LRMP, SLC2A3, TRIOBP, PIK3CG, RPS14, RPS19, GM2A, RGS1, ARHGDIB, COTL1, MYEOV2, RPS11, JUNB, RPS12, PDIA3, LYPLA2, RPS6, SSU72, CYBA, FOS, EMP3, VAV1, RAB32, DOK2, COX7A2L, TYROBP, PSMA4, DOK3, LTB4R1, IRF2, BTK, PRKD2, PRTN3, RPL27, PFN1, SGK1, HCST, GAPDH, PFDN5, H2-D1, LY6E, PRR13, CEBPB, CBFB, RPN2, PIRA4, CDCA7, WAS, ATP1A1, CST3, PRDX5, TCTEX1D2, PSAP, RPS3, INPP5K, NCKAP1L, NADK, BC037034, MCL1, OSBPL9, CD72, OSM, LAPTM5, RAB27A, ARPC5, AI467606, ARHGAP30, KLHL6, GNB2, RPL27A, ALOX5AP, PTPN6, CRLF3, LRP10, 2310016M24RIK, MYO1F</TD>
#  </TR>
# </TABLE>
# ChEA 2015: Down
# <TABLE cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;" border="1">
#  <TR>
#   <TH>Rank</TH>
#   <TH>Term</TH>
#   <TH>p-value</TH>
#   <TH>z-score</TH>
#   <TH>Combined Score</TH>
#   <TH>Related Genes</TH>
#  </TR>
#  <TR>
#   <TD>1</TD>
#   <TD>TAL1_ChIP-Seq_PRIMARY FETAL LIVER ERYTHROID _Mouse</TD>
#   <TD>5.3523e-87</TD>
#   <TD>-1.5340e+00</TD>
#   <TD>2.9561e+02</TD>
#   <TD>OTUD5, RPL3, CMAS, TFRC, ARL6IP1, SLC4A1, UBE2L6, AQP1, RABGEF1, UROD, FTH1, RNF19A, 5730469M10RIK, HIST1H2AD, HIST1H2AG, HIST1H2AF, TMEM14C, MAP2K3, TMOD1, BNIP3L, PAQR9, 2810453I06RIK, HIST1H2AN, HIST1H2AI, HIST1H2AH, DAPK2, IFRD2, ARRDC3, RFX2, GTPBP2, PRKAB1, CARHSP1, KEL, PSME3, BOLA3, SPNB1, IGTP, TXNIP, ABCG4, GYPA, TBCEL, FECH, GYPC, MGST3, ABCB4, SAMSN1, 2700029M09RIK, UGCG, ARHGAP21, UBB, PRKAR2B, FIGNL1, ST3GAL5, SLC38A5, HIST1H3E, KLHDC2, CDT1, UBE2H, SIVA1, H3F3B, GADD45A, UROS, STARD10, IRGM1, ASNS, MT1, SFRS2, AW146242, UBAC1, ISG20, 1700037H04RIK, DARC, EIF5, PQLC1, SLC6A9, TMCC2, GCLM, GSTM5, ALAS2, AHCTF1, CLIC4, FEN1, LDB1, ALAD, HEBP1, NPTN, ERMAP, TAPT1, CTSB, HIST1H1C, 2700097O09RIK, KLF13, SPHK1, 1190002H23RIK, GLRX5, H2AFX, ATPIF1, TUBB2C, 5730593F17RIK, TFDP2, MCM4, BIRC5, BLVRB, HAGH, CD47, ARF5, ANK, HEMGN, WBP2, ODC1, NT5C3, TRAK2, DNAJB2, DNAJB1, BTAF1, CD59A, LMNA, ACSS1, RBM38, CAR2, FAHD1, SMOX, SEMA4B, HNRNPAB, SOD1, KLF1, CSDA, GFI1B, KLF9, RHAG, NCAPD3, AGRN, SSBP3, GRINA</TD>
#  </TR>
#  <TR>
#   <TD>2</TD>
#   <TD>EKLF_ChIP-Seq_ERYTHROCYTE_Mouse</TD>
#   <TD>4.9856e-68</TD>
#   <TD>-1.6185e+00</TD>
#   <TD>2.4231e+02</TD>
#   <TD>RPL3, CD82, UBE2L6, ICAM4, SLC4A1, GHITM, MKI67, AQP1, TUBB5, RPS16, UROD, 5730469M10RIK, NUSAP1, HIST1H2AF, TMOD1, 2810453I06RIK, RPS8, DAPK2, RFX2, AP1B1, GTPBP2, ANK1, THOC4, THOC7, MORF4L2, RPL24, TRIM10, GYPA, TBCEL, FECH, MGST3, MRPL14, ADIPOR1, PRDX2, UGCG, NUP85, ST3GAL5, FN3K, PRNP, NFE2, CDT1, UBE2H, SIVA1, PHF10, GADD45A, EIF2AK1, ASNS, MT1, 2900010M23RIK, RPS26, 1810022K09RIK, SLC6A9, MAFG, RANBP10, UBE2O, TMCC2, GCLM, RPS24, ALAS2, DYRK3, FEN1, LDB1, MCM7, PIGQ, CETN3, FTL1, RPLP2, JOSD2, EEF1G, TFDP2, TAX1BP1, BLVRB, MCM4, MCM5, HAGH, MNS1, MCM2, HEMGN, WBP2, SLC43A1, DLST, PPOX, TSPAN33, NT5C3, TRAK2, FZR1, CD59A, E2F2, ACSS1, SNCA, RBM38, CAR2, TXNRD2, SMOX, SEMA4B, PDZK1IP1, SLC25A37, SH3YL1, SLC25A39, GRINA</TD>
#  </TR>
#  <TR>
#   <TD>3</TD>
#   <TD>GATA1_ChIP-Seq_MEL_Mouse</TD>
#   <TD>9.0245e-61</TD>
#   <TD>-1.5819e+00</TD>
#   <TD>2.1105e+02</TD>
#   <TD>OTUD5, ISCA1, CMAS, CD82, HBB-B2, BC022224, ICAM4, SLC4A1, UBE2L6, APEH, COMT, AQP1, SAMD14, PSMD4, FNTB, 5730469M10RIK, TMEM14C, TMOD1, BNIP3L, PAQR9, USP7, DAPK2, RFX2, PRKAB1, ANK1, HIST2H3B, KEL, BOLA3, SPNB1, TXNIP, TRIM10, ATF4, GYPA, TBCEL, FECH, GYPC, MGST3, ENDOD1, ADIPOR1, 2310003F16RIK, PRDX2, PRKAR2B, ST3GAL5, PSMF1, SPECC1, NFE2, SIVA1, GADD45A, UROS, EIF2AK1, MT1, DARC, COL5A1, SLC6A9, RANBP10, ANP32E, TMCC2, PSCD3, ALAS2, DYRK3, LDB1, PIGQ, ALAD, MYD116, CTSE, BCAS2, TAPT1, 2700097O09RIK, GPX1, GLRX5, NIPA1, 5730593F17RIK, PACS2, 2310022B05RIK, BLVRB, HAGH, CD47, ANK, HEMGN, WBP2, ODC1, SLC43A1, PPOX, CLCN3, TSPAN33, NT5C3, TRAK2, 4930570C03RIK, FZR1, LMNA, E2F2, ACSS1, SNCA, RBM38, CAR2, CAR1, FAHD1, TXNRD2, SEMA4B, GINS4, PDZK1IP1, KLF1, SLC25A38, HDGF, RHAG, 3300001G02RIK, SSBP3, BAT5</TD>
#  </TR>
#  <TR>
#   <TD>4</TD>
#   <TD>KLF1_ChIP-Seq_FETAL-LIVER-ERYTHROID_Mouse</TD>
#   <TD>1.5859e-41</TD>
#   <TD>-1.7938e+00</TD>
#   <TD>1.6135e+02</TD>
#   <TD>ALAS2, RNF11, CD82, SLC4A1, HBA-A1, HS6ST1, HEBP1, SAMD14, RNF19A, SEC61G, 5730469M10RIK, CTSB, USP7, KLF13, 2810453I06RIK, GPX1, RSAD2, PABPC4, DAPK2, 1190002H23RIK, LMO2, PRKAB1, ANK1, KEL, PSME3, CYB5, BLVRB, CD47, TRIM10, ARF5, ANK, HEMGN, GYPA, CCDC23, GYPC, WBP2, MGST3, SLC43A1, RPS27L, MRPL14, NT5C3, DEDD2, FAM132A, PRDX2, DNAJB1, UGCG, UBB, LMNA, E2F2, CDR2, FN3K, KLHDC2, NFE2, 3110056O03RIK, SIVA1, SMOX, EIF2AK1, BSDC1, LSM4, UBAC1, KLF1, SLC25A38, SH3YL1, 2210023G05RIK, GFI1B, CSDA, SLC6A9, LPCAT3, HDGF, SERINC1, TMCC2, GRINA</TD>
#  </TR>
#  <TR>
#   <TD>5</TD>
#   <TD>GATA2_ChIP-Seq_K562_Human</TD>
#   <TD>2.2570e-28</TD>
#   <TD>-2.1304e+00</TD>
#   <TD>1.2825e+02</TD>
#   <TD>OTUD5, RNF10, ALAS2, CLIC4, FEN1, CMAS, TFRC, LDB1, CD82, ARL6IP1, SLC4A1, NUDT4, AQP1, RABGEF1, UROD, FTH1, FNTB, TLK1, HMGN2, LBR, ERMAP, CTSB, TMEM14C, MAP2K3, TMOD1, BNIP3L, PAQR9, GPX1, RSAD2, LMO2, ATPIF1, RFX2, PRKAB1, ANK1, KEL, TFDP2, TAL1, ALDH1A1, BLVRB, PABPC1, HEMGN, FECH, GYPC, ENDOD1, BHLHB2, PPOX, CLCN3, ADIPOR1, TSPAN33, SAMSN1, DEDD2, TRAK2, DNAJB2, FZR1, TSPAN8, FIGNL1, E2F2, RHBDL2, SPECC1, RBM38, NFE2, CDT1, UBE2H, FAHD1, H3F3B, GADD45A, UROS, BSDC1, PDZK1IP1, UBAC1, KLF1, SLC25A37, GFI1B, SLC6A9, MKRN1, KLF9, UBE2O, HDGF, RHAG, TMCC2, SSBP3</TD>
#  </TR>
#  <TR>
#   <TD>6</TD>
#   <TD>MYC_ChIP-ChIP_MESC_Mouse</TD>
#   <TD>1.0727e-49</TD>
#   <TD>-1.1766e+00</TD>
#   <TD>1.2757e+02</TD>
#   <TD>RPL3, TFRC, ARL6IP1, ATP5C1, ICAM4, HS6ST1, EEF1B2, RPS16, TUBB5, UROD, FTH1, FNTB, NUSAP1, KNTC1, HIST1H2AF, MAP2K3, HIST1H2AN, HIST1H2AI, HIST1H2AH, RPS8, IFRD2, RPL23, GTPBP2, THOC4, HCFC1, NGFRAP1, PSME3, HAT1, RPL24, ANAPC5, UBA52, ATF4, GGNBP2, MGST3, COX17, CDCA8, 2310003F16RIK, PRDX2, CCNB1, UBB, NUP85, FIGNL1, SLC38A2, NDUFV1, HIST1H3E, HSPA8, CDT1, RPL41, SLMO2, SIVA1, H3F3B, ASNS, MT1, SFRS2, LSM4, SFRS1, RPS26, 1700037H04RIK, EIF5, SLC6A9, PQLC1, RPS29, MAFG, MKRN1, ANP32E, SERINC1, GCLM, RPS24, AARS, RNF10, AHCTF1, CLIC4, DYRK3, FEN1, MCM7, LDB1, CETN3, HIST2H2AB, ALAD, RPL7A, TUBA1B, FTL1, MYD116, NPTN, RPLP2, TLK1, BCAS2, GPX1, ATP6AP1, GLRX5, PABPC4, H2AFX, ATPIF1, RPS3A, RANGAP1, TUBB2C, 5730593F17RIK, NDUFS7, EEF1D, MCM4, MCM5, MCM6, PABPC1, HAGH, MCM2, UHRF1, ODC1, RPL36A, RPS27L, CLCN3, NT5C3, CENPA, DNAJB1, E2F1, RPS2, RBM38, FAHD1, RIOK3, GINS4, RPA1, ORC6L, DEK, COX6C, SOD1, CSDA, PHF5A, SLC25A39, KLF9, CENPL, HDGF, NCAPD3, 3300001G02RIK, SSBP3</TD>
#  </TR>
#  <TR>
#   <TD>7</TD>
#   <TD>GATA1_ChIP-Seq_K562_Human</TD>
#   <TD>1.8252e-23</TD>
#   <TD>-2.5745e+00</TD>
#   <TD>1.2745e+02</TD>
#   <TD>HEMGN, DYRK3, TFRC, ARL6IP1, ETFA, SLC4A1, CLCN3, PPOX, ADIPOR1, TSPAN33, SAMSN1, DEDD2, AQP1, DNAJB2, TUBA1B, PRKAR2B, UROD, FIGNL1, FTH1, TLK1, HMGN2, LBR, ERMAP, CTSB, RBM38, BNIP3L, NFE2, CDT1, UBE2H, RSAD2, GADD45A, LMO2, BSDC1, PDZK1IP1, PRKAB1, ANK1, UBAC1, KLF1, SLC25A37, GFI1B, KEL, SLC6A9, TFDP2, TAL1, KLF9, UBE2O, BLVRB, TMCC2</TD>
#  </TR>
#  <TR>
#   <TD>8</TD>
#   <TD>MYC_ChIP-ChIP_MESC_Mouse</TD>
#   <TD>2.2240e-41</TD>
#   <TD>-1.3889e+00</TD>
#   <TD>1.2464e+02</TD>
#   <TD>RPL3, TFRC, ARL6IP1, ATP5C1, BC022224, EEF1B2, TUBB5, FNTB, NUSAP1, TMEM14C, MAP2K3, PAQR9, RPS8, IFRD2, RPL23, GTPBP2, PRKAB1, THOC4, HCFC1, HIST2H3B, MORF4L2, PSME3, RPL24, UBA52, ATF4, CDCA8, ADIPOR1, 2310003F16RIK, DEDD2, PRDX2, CCNB1, UBB, NUP85, CDT1, RPL41, H3F3B, UROS, EIF2AK1, ASNS, MT1, SFRS2, LSM4, 2900010M23RIK, SFRS1, RPS26, 1700037H04RIK, EIF5, SLC6A9, RPS29, MKRN1, SERINC1, RPS24, AARS, RNF10, AHCTF1, DYRK3, FEN1, MCM7, LDB1, MRPS12, CETN3, ALAD, RPL7A, FTL1, MYD116, SEC61G, RPLP2, LBR, BCAS2, 2700097O09RIK, KLF13, GPX1, GLRX5, H2AFX, ATPIF1, RPS3A, KIF22, RANGAP1, EEF1G, TUBB2C, 5730593F17RIK, EEF1D, 2310022B05RIK, MCM4, MCM5, MCM6, MNS1, PABPC1, HAGH, UHRF1, ODC1, RPL36A, RPS27L, DLST, CLCN3, NT5C3, DNAJB1, FZR1, RPS2, RBM38, 3110056O03RIK, FAHD1, RPA1, ORC6L, SOD1, SLC25A37, CSDA, PHF5A, SLC25A39, PRC1, KLF9, CENPL, HDGF, 3300001G02RIK, BAT5</TD>
#  </TR>
#  <TR>
#   <TD>9</TD>
#   <TD>MYC_ChIP-ChIP_MESC_Mouse</TD>
#   <TD>9.6315e-27</TD>
#   <TD>-2.0038e+00</TD>
#   <TD>1.1342e+02</TD>
#   <TD>RB1, RPL3, LDB1, MCM7, ATP5C1, ICAM4, ALAD, EEF1B2, RPL7A, TUBB5, RPS16, RPLP2, 1300017J02RIK, BCAS2, GPX1, ATP6AP1, RPS8, RPL23, ATPIF1, DNTTIP1, RPS3A, GTPBP2, THOC4, EEF1G, PSME3, MORF4L2, BIRC5, TXNIP, RPL24, HAGH, UBA52, ODC1, RPL36A, CDCA8, RPS27L, 2310003F16RIK, DEDD2, CCNB1, NUP85, FIGNL1, LMNA, RPS2, SLC38A2, HSPA8, 2510006D16RIK, RPL41, EIF2AK1, DEK, SFRS2, COX6C, SOD1, RPS26, TUBA6, EIF5, SLC25A39, PHF5A, RPS29, KLF9, ANP32E, HDGF, RPS24, AARS</TD>
#  </TR>
#  <TR>
#   <TD>10</TD>
#   <TD>E2F1_ChIP-Seq_MESC_Mouse</TD>
#   <TD>3.7399e-43</TD>
#   <TD>-1.1492e+00</TD>
#   <TD>1.0750e+02</TD>
# PPI Hub Proteins: Up
# <TABLE cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;" border="1">
#  <TR>
#   <TH>Rank</TH>
#   <TH>Term</TH>
#   <TH>p-value</TH>
#   <TH>z-score</TH>
#   <TH>Combined Score</TH>
#   <TH>Related Genes</TH>
#  </TR>
#  <TR>
#   <TD>1</TD>
#   <TD>SLC2A4</TD>
#   <TD>2.6574e-28</TD>
#   <TD>-1.2142e+00</TD>
#   <TD>7.0164e+01</TD>
#   <TD>EIF4A1, HIBADH, RPL31, ARPC1B, ENO1, RPL10A, RPL9, ACTB, RPS14, LGALS1, ALDH2, RPS19, ACADM, ATP6V1E1, RPS11, PRKACB, RPS13, RPS12, CAP1, PDIA3, RPS9, SSR4, ANXA2, ACTN1, STX7, RPS6, NME2, MIF, PGD, APRT, EEF1A1, MYL4, ACLY, PSMA4, ERP29, RPL27, SGK1, PFN1, SLC25A5, GAPDH, VCP, RPN2, GSTP1, LYZ2, ATP1A1, COX5A, GNAI2, PRDX5, LDHA, RPS3, RPL18, ATP6V1D, PKM2, DSTN, PPP1CA, GNB2, MAN2B1, DYNLRB1, P4HB</TD>
#  </TR>
#  <TR>
#   <TD>2</TD>
#   <TD>IL7R</TD>
#   <TD>6.8664e-14</TD>
#   <TD>-1.8325e+00</TD>
#   <TD>4.7626e+01</TD>
#   <TD>PDIA3, VCP, GSTP1, F13A1, ARPC5, ENO1, ACTB, APRT, MYL6, LGALS1, ZYX, COTL1, ERP29, PTPN6, TAGLN2, P4HB, LCP1, PFN1, GAPDH, CLIC1</TD>
#  </TR>
#  <TR>
#   <TD>3</TD>
#   <TD>ACTB</TD>
#   <TD>1.7428e-16</TD>
#   <TD>-1.4316e+00</TD>
#   <TD>4.4769e+01</TD>
#   <TD>APP, ARPC1B, WAS, ARRB2, IQGAP1, ENO1, CORO1A, ACTB, GNAI2, PSTPIP1, LASP1, RPS19, TMSB4X, RAC2, RPL18, S100A11, RPS13, RPS12, MCL1, CAP1, RPS9, ANXA2, ACTN1, DSTN, ARPC5, MYL4, EEF1A1, MYL6, MARCKS, ARPC3, ZYX, PFN1, GAPDH</TD>
#  </TR>
#  <TR>
#   <TD>4</TD>
#   <TD>GABARAPL1</TD>
#   <TD>7.3071e-15</TD>
#   <TD>-1.2669e+00</TD>
#   <TD>3.5398e+01</TD>
#   <TD>EIF4A1, RPL31, GSTP1, ENO1, RPL10A, RPL9, PIK3CG, ACTB, ATP5L, RPS14, LDHA, ALDH2, RPS19, RASSF5, RPS3, ACADM, RPL18, CLIC1, S100A11, RPS13, PDIA3, RPS9, SSR4, ANXA2, PKM2, ACTN1, RPS6, MIF, EEF1A1, MYL6, RPL27, TAGLN2, PFN1, SLC25A5, GAPDH, PPIA, S100A8</TD>
#  </TR>
#  <TR>
#   <TD>5</TD>
#   <TD>EIF1B</TD>
#   <TD>1.8136e-10</TD>
#   <TD>-1.5713e+00</TD>
#   <TD>2.9336e+01</TD>
#   <TD>RPS9, ANXA2, RPL32, SSR4, RPL31, DSTN, TALDO1, MIF, TBCA, RHOB, RPS14, MYL6, RPS19, TAGLN2, EIF3F, RPS11, RPL29, GAPDH</TD>
#  </TR>
#  <TR>
#   <TD>6</TD>
#   <TD>GC20</TD>
#   <TD>2.2043e-09</TD>
#   <TD>-1.7424e+00</TD>
#   <TD>2.9117e+01</TD>
#   <TD>RPS9, ANXA2, RPL32, SSR4, RPL31, TALDO1, DSTN, MIF, TBCA, EIF3S5, RPS14, MYL6, RPS19, CALM3, TAGLN2, RPS11, RPL29</TD>
#  </TR>
#  <TR>
#   <TD>7</TD>
#   <TD>HNRNPK</TD>
#   <TD>3.2806e-10</TD>
#   <TD>-1.5497e+00</TD>
#   <TD>2.8404e+01</TD>
#   <TD>EIF4A1, CEBPB, ANXA2, RPL31, MIF, ARRB2, IQGAP1, ENO1, RPL9, ACTB, VAV1, EEF1A1, RPS14, RPS19, ALDH2, RPS3, CSK, PRKACB, S100A11</TD>
#  </TR>
#  <TR>
#   <TD>8</TD>
#   <TD>IKBKE</TD>
#   <TD>1.0023e-11</TD>
#   <TD>-1.0847e+00</TD>
#   <TD>2.3027e+01</TD>
#   <TD>VCP, RPL32, RPL31, GLO1, PYGL, ACTB, RPS14, PRDX5, RPS19, COTL1, RPS11, CLIC1, TPD52, RPS9, ANXA2, DSTN, TALDO1, TBCA, MIF, PGD, APRT, EEF1A1, ACLY, MYL6, GNB2, ERP29, CALM3, TAGLN2, PLP2, EIF3F, PFDN5</TD>
#  </TR>
#  <TR>
#   <TD>9</TD>
#   <TD>YWHAZ</TD>
#   <TD>4.2852e-10</TD>
#   <TD>-1.2236e+00</TD>
#   <TD>2.2227e+01</TD>
#   <TD>EIF4A1, APP, VCP, RPL31, PNKP, LRMP, ENO1, IQGAP1, RPL10A, ACTB, LDHA, LGALS1, RPS3, PGLYRP1, PRKACB, NADK, MARK2, TPD52, NAPSA, ANXA2, PKM2, NME2, SCAMP2, EEF1A1, ADSSL1, EIF3F, P4HB, PFN1, GAPDH, PPIA</TD>
#  </TR>
#  <TR>
#   <TD>10</TD>
#   <TD>GRB2</TD>
#   <TD>2.3474e-11</TD>
#   <TD>-1.0698e+00</TD>
#   <TD>2.1995e+01</TD>
#   <TD>EIF4A1, APP, WDR1, RPL31, GSTP1, POMP, WAS, HP, ENO1, IQGAP1, PIK3CG, RPS14, CCL5, RPS6KA1, RPS3, RPL18, RPS11, B2M, NADK, RPS13, RPS9, CD72, ANXA2, PKM2, ACTN1, ARPC5, VAV1, EEF1A1, MYL6, DOK3, SELL, ARPC3, RPL27A, BTK, LY6D, RIN3, PTPN6, RPL27, HCST, PPIA</TD>
#  </TR>
# </TABLE>
# PPI Hub Proteins: Down
# <TABLE cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;" border="1">
#  <TR>
#   <TH>Rank</TH>
#   <TH>Term</TH>
#   <TH>p-value</TH>
#   <TH>z-score</TH>
#   <TH>Combined Score</TH>
#   <TH>Related Genes</TH>
#  </TR>
#  <TR>
#   <TD>1</TD>
#   <TD>ARRB2</TD>
#   <TD>9.3831e-10</TD>
#   <TD>-1.4449e+00</TD>
#   <TD>2.1800e+01</TD>
#   <TD>HSPA8, RPL3, RPS8, PABPC4, H2AFX, HIST2H2AB, AP1B1, RPA1, RPS3A, RANGAP1, THOC4, ARHGAP21, RPL7A, TUBB2C, CSDA, UBB, NDUFS7, RPLP2, PABPC1, LBR, UBA52, S100A9, HIST1H1C</TD>
#  </TR>
#  <TR>
#   <TD>2</TD>
#   <TD>SLC2A4</TD>
#   <TD>1.7091e-09</TD>
#   <TD>-1.1979e+00</TD>
#   <TD>1.8073e+01</TD>
#   <TD>DLST, ATP5C1, ETFA, ATP5H, RPL7A, PRDX2, TUBA1B, TUBB5, RPS16, LMNA, PSMD1, RPS2, NDUFV1, CTSB, RAB8B, HSPA8, ATP6AP1, RPS8, ACSL1, RPL23, RPS3A, DYNLL1, HNRNPAB, TUBB2C, CSDA, EEF1D, TXNIP, RPL24, PABPC1, UBA52, ARF5, RPS24</TD>
#  </TR>
#  <TR>
#   <TD>3</TD>
#   <TD>MCC</TD>
#   <TD>1.0995e-07</TD>
#   <TD>-1.5132e+00</TD>
#   <TD>1.7915e+01</TD>
#   <TD>CLIC4, TFRC, MCM7, RPS3A, MRPL14, ETFA, COMT, APEH, EEF1B2, PSMD8, EEF1D, EIF3I, PSME3, RPL24, MCM4, MCM5, MCM6, GCLM, BCAS2</TD>
#  </TR>
#  <TR>
#   <TD>4</TD>
#   <TD>GABARAPL2</TD>
#   <TD>1.0485e-08</TD>
#   <TD>-1.2534e+00</TD>
#   <TD>1.7145e+01</TD>
#   <TD>RPL3, MCM7, WBP2, DLST, EEF1B2, RPL7A, PRDX2, RPS16, PSMD1, RPLP2, RPS2, HIST1H1C, HSPA8, RPS8, RPL23, PABPC4, PLRG1, RANGAP1, THOC4, HNRNPAB, EEF1G, TUBB2C, CSDA, UBE2O, RPL24, PABPC1, S100A9, RPS24</TD>
#  </TR>
#  <TR>
#   <TD>5</TD>
#   <TD>TRAF6</TD>
#   <TD>2.1502e-07</TD>
#   <TD>-1.3874e+00</TD>
#   <TD>1.5962e+01</TD>
#   <TD>RNF11, TFRC, MCM7, ETFA, PSMD8, PSMD4, UBB, PSMD1, HSPA8, USP7, RSAD2, SPHK1, RPS3A, RANGAP1, RPS26, CARHSP1, NGFRAP1, EIF3K, EEF1D, EIF3I, CYB5, RPA3, TAX1BP1, RPL24, MCM6, PABPC1</TD>
#  </TR>
#  <TR>
#   <TD>6</TD>
#   <TD>GABARAP</TD>
#   <TD>6.2624e-08</TD>
#   <TD>-1.2886e+00</TD>
#   <TD>1.5695e+01</TD>
#   <TD>RPL3, TFRC, WBP2, EEF1B2, RPL7A, PRDX2, RPS16, RPLP2, RPS2, BCAS2, HIST1H1C, HSPA8, RPS8, RPL23, PABPC4, PLRG1, HNRNPAB, EEF1G, TUBB2C, CSDA, PSME3, HAT1, RPL24, PABPC1, RPS24</TD>
#  </TR>
#  <TR>
#   <TD>7</TD>
#   <TD>EIF1B</TD>
#   <TD>1.1268e-06</TD>
#   <TD>-1.5131e+00</TD>
#   <TD>1.5442e+01</TD>
#   <TD>RPL3, RPS3A, ETFA, UBAC1, RPS26, EEF1B2, RPS16, EIF3K, EEF1D, RPS29, EIF3I, PSME3, RPA3</TD>
#  </TR>
#  <TR>
#   <TD>8</TD>
#   <TD>MCM2</TD>
#   <TD>3.0478e-05</TD>
#   <TD>-1.9790e+00</TD>
#   <TD>1.5120e+01</TD>
#   <TD>CDT1, MCM7, RPA3, HAT1, RPA1, ORC6L, MCM4, MCM5, MCM6, MCM2</TD>
#  </TR>
#  <TR>
#   <TD>9</TD>
#   <TD>GABARAPL1</TD>
#   <TD>1.3194e-07</TD>
#   <TD>-1.2197e+00</TD>
#   <TD>1.4440e+01</TD>
#   <TD>RPL3, WBP2, ATP5C1, EEF1B2, RPL7A, DNAJB1, PRDX2, RPS16, LMNA, RPLP2, RPS2, SNCA, HIST1H1C, HSPA8, RPS8, PABPC4, HNRNPAB, THOC4, EEF1G, TUBB2C, RPL24, MCM5, PABPC1, S100A9, RPS24</TD>
#  </TR>
#  <TR>
#   <TD>10</TD>
#   <TD>ACTB</TD>
#   <TD>9.4975e-07</TD>
#   <TD>-1.3162e+00</TD>
#   <TD>1.3519e+01</TD>
#   <TD>HSPA8, CLIC4, RPS8, RPA1, RPS3A, DYNLL1, CENPA, HNRNPAB, EEF1B2, RPL7A, EIF3K, UBB, EIF3I, MORF4L2, RPA3, LMNA, RPS24, SNCA, RAB8B</TD>
#  </TR>
# </TABLE>

# %% [markdown]
# ### Canvas Visualization of Enrichment Results
# Below is a canvas representation of the results from enrichment analysis. Each canvas is composed of tiles, representing enrichment library terms. The arrangement of tiles is determined using a simulated annealing algorithm, [_Network2Canvas_](http://www.maayanlab.net/N2C/) which attempts to position terms together based on network similarity. The layout of tiles is identical for each library, and the brightness of each tile is proportional to the enrichment score of the corresponding term. Also note that each canvas is a torus, ie. opposite edges border one another. Each canvas is annotated with relevant terms and p-values.

# %%
Image(filename='GATA1 Enrichment Canvases.png', width=1100, height=800)

# %% [markdown]
# #### Phenotypes
# Every one of the top-ten enrichment terms for up-regulated genes was related to abnormal immune system phenotypes. This included enrichment for both innate and adaptive immunity abnormalities, as well as abnormal blood cells, immune cells, and blood marrow. Highly enriched terms also include "abnormal antigen presenting", "abnormal immune serum", "abnormal response to infection”, and “abnormal humoral immune response”.
#
# Among down-regulated genes, the phenotype for "abnormal erythrocyte physiology“ was the most highly ranked. Abnormal blood cells and bone marrow were also highly ranked. Together, these terms imply that the GATA1 plays an important role in the normal function of the immune system.
#
#
# #### Pathways
# Among Wikipathways terms, we found enrichment for hematopoiesis-related pathways in both up- and down-regulated genes. Up-regulated genes showed enrichment for Toll-like receptor signaling as well as B Cell receptor signaling.  Toll-like receptors mediate RAC and are responsible for activating the innate immune system. The term “IL1 and megakaryocytes in obesity” was also significantly enriched among up-regulated genes. IL1 is a proinflammatory cytokine and activates the p38/MAPK pathway in megakaryocytes. It is also implicated in Toll-like receptor signaling.
#
# The most enriched pathway among down-regulated genes was G1 to S Cell Cycle control. We found enrichment for the Heme Biosynthesis, with genes such as ALAD, ALAS2, FECH, UROD, UROS, and PPOX implicated. Notably, TGF-beta signaling pathway was low on the list of enrichment terms for both up- and down-regulated genes. However, this is likely be due to the fact that GATA1 participates in a non-canonical TGF-beta signaling pathway and may not be represented by the Wikipathways library.
#
#
# #### Transcription Factors
# Firstly, we note that GATA1 and GATA2 appeared several times among the top ChEA terms for down-regulated genes, giving confidence to the strength of the enrichment results.
#
# The two highest-ranked ChEA terms among up-regulated genes was MYB and MECOM, both of which are transcription factors that play important roles in the regulation of hematopoiesis. Additionally, there is evidence that MECOM, also known as EVI1, plays a role in apoptosis via the TGF-beta signaling pathway. Other transcription factor regulators of the immune system were also enriched, including SPI1, STAT1, and STAT4. The transcription factor EKLF, also known as KLF1, was highly enriched in both up- and down-regulated gene sets, and is necessary for erythroid maturation.
#
# Among down-regulated genes, the most highest-enriched transcription factor was TAL1. Also enriched among up-regulated genes, this transcription factor is a positive regulator of erythroid differentiation and has been implicated in hematopoiesis. Well-known transcription factor MYC also appeared several times among down-regulated enrichment terms. It plays a role in PI3K-Akt and MAPK signaling pathways.
#
#
# #### Hub Proteins
# For both up- and down-regulated genes, the protein SLC2A4 was among the most highly enriched. This protein transports glucose across the cell membrane in response to insulin. Also highly enriched among up-regulated genes was IL7R, a receptor protein that is expressed in T lymphocytes.  Also of note is protein kinase IKBKE, which regulates the viral inflammatory response and is known to phosphorylate STAT1 and AKT1.
#
# Among down-regulated genes, the most highly enriched hub protein was ARRB2. This protein is involved in GPCR desensitization and acts as signaling scaffold for MAPK pathways, such as ERK1/2. It has also been implicated in Toll-like receptor and IL-1 receptor signaling through interaction with TRAF6, a transcription factor that is also enriched among down-regulated genes.
#
# ### L1000CDS2 Analysis
#
# We submitted the up- and down-regulated gene lists to L1000CDS2. This tool searches through the LINCS L1000 data for small-molecule gene signatures that may reverse or mimic your input signature, allowing us to compare the GATA1-knockout characteristic direction (CD) differential expression signature with the CD signatures of nearly 4,000 small-molecules. This is done by computing the signatures with the greatest (reverse) or least (mimic) cosine distance between the CD signature vectors. A full description of the method can be found on the [_help page_](http://amp.pharm.mssm.edu/L1000CDS2/help/), and you can browse the full results on the site:
#
# * [_Small Molecules that REVERSE the GATA1-KO Signature_](http://amp.pharm.mssm.edu/L1000CDS2/#/result/573bb8b06832f28301aa0c23)
# * [_Small Molecules that MIMIC the GATA1-KO Signature_](http://amp.pharm.mssm.edu/L1000CDS2/#/result/573bb8c36832f28301aa0c25)

# %%
reverse = pd.read_table('L1000CDS2_GATA1-KO_reverse.txt',sep='\t')
mimic = pd.read_table('L1000CDS2_GATA1-KO_mimic.txt',sep='\t')

# Plot the tables
print "Small Molecules that REVERSE the GATA1-KO Signature"
fields = list(reverse.columns.values)
htmlcode = table2html.table(reverse.values.tolist()[:10], header_row=fields)
display(ipyHTML(htmlcode))
print "Small Molecules that MIMIC the GATA1-KO Signature"
fields = list(mimic.columns.values)
htmlcode = table2html.table(mimic.values.tolist()[:10],header_row=fields)
display(ipyHTML(htmlcode))
# Out:
# Small Molecules that REVERSE the GATA1-KO Signature
# <TABLE cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;" border="1">
#  <TR>
#   <TH>﻿Rank</TH>
#   <TH>1-cos(α)</TH>
#   <TH>Perturbation</TH>
#   <TH>Perturbation LIFE URL</TH>
#   <TH>Perturbation PubChem URL</TH>
#   <TH>Perturbation DrugBank URL</TH>
#   <TH>Cell-line</TH>
#   <TH>Dose</TH>
#   <TH>Time</TH>
#   <TH>Signature URL</TH>
#  </TR>
#  <TR>
#   <TD>1</TD>
#   <TD>1.2628</TD>
#   <TD>RAF 265</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K93123848</TD>
#   <TD>None</TD>
#   <TD>None</TD>
#   <TD>A549</TD>
#   <TD>0.04um</TD>
#   <TD>24h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=LJP009_A549_24H:BRD-K93123848:0.04</TD>
#  </TR>
#  <TR>
#   <TD>2</TD>
#   <TD>1.2564</TD>
#   <TD>PRIMA-1 MET</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K49456190</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=73707386</TD>
#   <TD>None</TD>
#   <TD>HT115</TD>
#   <TD>10.0um</TD>
#   <TD>6.0h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=CPC006_HT115_6H:BRD-K49456190:10.0</TD>
#  </TR>
#  <TR>
#   <TD>3</TD>
#   <TD>1.254</TD>
#   <TD>lapatinib</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K19687926</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=208908</TD>
#   <TD>http://www.drugbank.ca/drugs/DB01259</TD>
#   <TD>HME1</TD>
#   <TD>0.04um</TD>
#   <TD>3h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=LJP006_HME1_3H:BRD-K19687926:0.04</TD>
#  </TR>
#  <TR>
#   <TD>4</TD>
#   <TD>1.2522</TD>
#   <TD>gefitinib</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K64052750</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=123631</TD>
#   <TD>http://www.drugbank.ca/drugs/DB00317</TD>
#   <TD>HME1</TD>
#   <TD>0.12um</TD>
#   <TD>3h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=LJP006_HME1_3H:BRD-K64052750:0.12</TD>
#  </TR>
#  <TR>
#   <TD>5</TD>
#   <TD>1.2503</TD>
#   <TD>gefitinib</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K64052750</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=123631</TD>
#   <TD>http://www.drugbank.ca/drugs/DB00317</TD>
#   <TD>HME1</TD>
#   <TD>1.11um</TD>
#   <TD>3h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=LJP006_HME1_3H:BRD-K64052750:1.11</TD>
#  </TR>
#  <TR>
#   <TD>6</TD>
#   <TD>1.2465</TD>
#   <TD>CC-401</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K45746021</TD>
#   <TD>None</TD>
#   <TD>None</TD>
#   <TD>PC3</TD>
#   <TD>3.33um</TD>
#   <TD>24h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=LJP009_PC3_24H:BRD-K45746021:3.33</TD>
#  </TR>
#  <TR>
#   <TD>7</TD>
#   <TD>1.2458</TD>
#   <TD>radicicol</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-A39996500</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=5311380</TD>
#   <TD>None</TD>
#   <TD>SKBR3</TD>
#   <TD>1.11um</TD>
#   <TD>24h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=LJP006_SKBR3_24H:BRD-A39996500:1.11</TD>
#  </TR>
#  <TR>
#   <TD>8</TD>
#   <TD>1.2376</TD>
#   <TD>Lonidamine</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K78513633</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=39562</TD>
#   <TD>None</TD>
#   <TD>HT29</TD>
#   <TD>177.6um</TD>
#   <TD>24.0h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=CPC006_HT29_24H:BRD-K78513633:177.6</TD>
#  </TR>
#  <TR>
#   <TD>9</TD>
#   <TD>1.2329</TD>
#   <TD>483-63-6</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K57179821</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=688020</TD>
#   <TD>http://www.drugbank.ca/drugs/DB00265</TD>
#   <TD>VCAP</TD>
#   <TD>10.0um</TD>
#   <TD>24.0h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=CPC011_VCAP_24H:BRD-K57179821:10.0</TD>
#  </TR>
#  <TR>
#   <TD>10</TD>
#   <TD>1.2327</TD>
#   <TD>CAY10594</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K61662457</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=56588033</TD>
#   <TD>None</TD>
#   <TD>SNUC4</TD>
#   <TD>20.0um</TD>
#   <TD>6.0h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=CPC006_SNUC4_6H:BRD-K61662457:20.0</TD>
#  </TR>
# </TABLE>
# Small Molecules that MIMIC the GATA1-KO Signature
# <TABLE cellpadding="4" style="border: 1px solid #000000; border-collapse: collapse;" border="1">
#  <TR>
#   <TH>﻿Rank</TH>
#   <TH>1-cos(α)</TH>
#   <TH>Perturbation</TH>
#   <TH>Perturbation LIFE URL</TH>
#   <TH>Perturbation PubChem URL</TH>
#   <TH>Perturbation DrugBank URL</TH>
#   <TH>Cell-line</TH>
#   <TH>Dose</TH>
#   <TH>Time</TH>
#   <TH>Signature URL</TH>
#  </TR>
#  <TR>
#   <TD>1</TD>
#   <TD>0.7042</TD>
#   <TD>INK-128</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K59317601</TD>
#   <TD>None</TD>
#   <TD>None</TD>
#   <TD>HT29</TD>
#   <TD>1.11um</TD>
#   <TD>24h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=LJP007_HT29_24H:BRD-K59317601:1.11</TD>
#  </TR>
#  <TR>
#   <TD>2</TD>
#   <TD>0.7061</TD>
#   <TD>gefitinib</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K64052750</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=123631</TD>
#   <TD>http://www.drugbank.ca/drugs/DB00317</TD>
#   <TD>HCC515</TD>
#   <TD>1.11um</TD>
#   <TD>24h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=LJP006_HCC515_24H:BRD-K64052750:1.11</TD>
#  </TR>
#  <TR>
#   <TD>3</TD>
#   <TD>0.7155</TD>
#   <TD>vandetanib</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K77625799</TD>
#   <TD>None</TD>
#   <TD>None</TD>
#   <TD>A375</TD>
#   <TD>3.33um</TD>
#   <TD>24h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=LJP007_A375_24H:BRD-K77625799:3.33</TD>
#  </TR>
#  <TR>
#   <TD>4</TD>
#   <TD>0.7337</TD>
#   <TD>BRD-K49010888</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K49010888</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=44507260</TD>
#   <TD>None</TD>
#   <TD>HEPG2</TD>
#   <TD>10.0um</TD>
#   <TD>6.0h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=CPC019_HEPG2_6H:BRD-K49010888:10.0</TD>
#  </TR>
#  <TR>
#   <TD>5</TD>
#   <TD>0.734</TD>
#   <TD>Ingenol 3, 20-dibenzoate</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-A52650764</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=5225086</TD>
#   <TD>None</TD>
#   <TD>SW620</TD>
#   <TD>10.0um</TD>
#   <TD>6.0h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=CPC006_SW620_6H:BRD-A52650764:10.0</TD>
#  </TR>
#  <TR>
#   <TD>6</TD>
#   <TD>0.7359</TD>
#   <TD>BRD-K05549170</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K05549170</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=1167614</TD>
#   <TD>None</TD>
#   <TD>A549</TD>
#   <TD>10.0um</TD>
#   <TD>6.0h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=CPC008_A549_6H:BRD-K05549170:10.0</TD>
#  </TR>
#  <TR>
#   <TD>7</TD>
#   <TD>0.7372</TD>
#   <TD>BRD-K77908580</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K77908580</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=4261</TD>
#   <TD>None</TD>
#   <TD>HEPG2</TD>
#   <TD>10.0um</TD>
#   <TD>6.0h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=CPC013_HEPG2_6H:BRD-K77908580:10.0</TD>
#  </TR>
#  <TR>
#   <TD>8</TD>
#   <TD>0.7408</TD>
#   <TD>F9428</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K14791739</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=73707412</TD>
#   <TD>None</TD>
#   <TD>A549</TD>
#   <TD>10.0um</TD>
#   <TD>24.0h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=CPC013_A549_24H:BRD-K14791739:10.0</TD>
#  </TR>
#  <TR>
#   <TD>9</TD>
#   <TD>0.742</TD>
#   <TD>HY-50295</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K05104363</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=6918454</TD>
#   <TD>None</TD>
#   <TD>NPC</TD>
#   <TD>10.0um</TD>
#   <TD>24.0h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=CPC014_NPC_24H:BRD-K05104363:10.0</TD>
#  </TR>
#  <TR>
#   <TD>10</TD>
#   <TD>0.7429</TD>
#   <TD>S1299</TD>
#   <TD>http://life.ccs.miami.edu/life/summary?mode=SmallMolecule&source=BROAD&input=BRD-K47832606</TD>
#   <TD>http://pubchem.ncbi.nlm.nih.gov/summary/summary.cgi?cid=5790</TD>
#   <TD>http://www.drugbank.ca/drugs/DB00322</TD>
#   <TD>A549</TD>
#   <TD>10.0um</TD>
#   <TD>24.0h</TD>
#   <TD>http://amp.pharm.mssm.edu/L1000CDS2/meta?sig_id=CPC013_A549_24H:BRD-K47832606:10.0</TD>
#  </TR>
# </TABLE>

# %% [markdown]
# ## Conclusions
# Together, enrichment analysis supports the hypothesis that GATA1 is involved in a non-canonical MAPK-dependent activation of TFG-beta signaling in primary myelofibrotic mice. The strong signal for the abnormal immune system phenotype distinctly indicates an autoimmune response by up-regulated genes. Furthermore, enrichment for the Toll-like receptor pathway and the IL1 pathway in megakaryocytes indicates that this response may be due to the MAPK-activated non-canonical TGF-beta pathway. Particularly, this gives strength to hypothesis that this process is driven by megakaryocyte death. Enrichment results for proteins and transcription factors such as ARRB2, MYB, MECOM (EVI1), and STAT1 also implicate MAPK signaling, and provide greater evidence that EVI1 may be downstream of the p38/MAPK signaling pathway of megakaryopoiesis in primary myelofibrosis.
